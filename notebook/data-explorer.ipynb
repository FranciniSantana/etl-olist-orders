# %% [markdown]
# # Análise Exploratória de dados

# %%
#!pip install numpy==2.2.3
#!pip install pandas
#print(np.__version__)
# !pip install ydata-profiling[notebook]
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# ...
#      -------------------------------------- 400.4/400.4 kB 6.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 64.7/64.7 kB 3.4 MB/s eta 0:00:00
# ...
#      ------------------------------------- 306.2/306.2 kB 18.5 MB/s eta 0:00:00
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#   Using cached multimethod-1.12-py3-none-any.whl (10 kB)
# ...
#      --------------------------------------- 41.3/41.3 MB 11.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.1/3.1 MB 6.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 8.0/8.0 MB 12.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.7/2.7 MB 8.7 MB/s eta 0:00:00
# ...
#      ------------------------------------- 463.6/463.6 kB 14.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 9.6/9.6 MB 12.5 MB/s eta 0:00:00
# ...
#   Using cached visions-0.8.1-py3-none-any.whl (105 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# ...

# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

# %%
## path de arquivos

customers        = r"..\data\olist_customers_dataset.csv"
geolocation      = r"..\data\olist_geolocation_dataset.csv"
order_items      = r"..\data\olist_order_items_dataset.csv"
order_payments   = r"..\data\olist_order_payments_dataset.csv"
order_reviews    = r"..\data\olist_order_reviews_dataset.csv"
orders           = r"..\data\olist_orders_dataset.csv"
products         = r"..\data\olist_products_dataset.csv"
sellers          = r"..\data\olist_sellers_dataset.csv"
product_category = r"..\data\product_category_name_translation.csv"

# %%
df_customers        = pd.read_csv(customers,sep=",")
df_geolocation      = pd.read_csv(geolocation,sep=",")
df_order_items      = pd.read_csv(order_items,sep=",")
df_order_payments   = pd.read_csv(order_payments,sep=",")
df_order_reviews    = pd.read_csv(order_reviews, sep=",")
df_orders           = pd.read_csv(orders,sep=",")
df_products         = pd.read_csv(products,sep=",")
df_sellers          = pd.read_csv(sellers, sep=",")
df_product_category = pd.read_csv(product_category,sep=",")

# %%
# Gerando Report de análise exploratória em arquivo html teste 
df_customers_profile = ProfileReport(df_customers, title="Profiling Report df_customers")
df_customers_profile.to_file("df_customers.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Dicionário com os dataframes para gerar os relatórios dos demais dataframes para evitar repetir código

lista_dfs = {"df_geolocation": df_geolocation,
             "df_order_items": df_order_items,
             "df_order_payments" : df_order_payments,
             "df_order_reviews" : df_order_reviews,
             "df_orders": df_orders,
             "df_products": df_products,
             "df_sellers": df_sellers,
             "df_product_category": df_product_category
}

# %%
for nome, df in lista_dfs.items():
   df = ProfileReport(df, title= f"Profiling Report {nome}")
   df.to_file(f"{nome}.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
